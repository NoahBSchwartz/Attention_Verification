# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

def f1(x1, x2):
    return x2

def f2(x1, x2):
    return -x1 + (1/3)*x1**3 - x2

x1_range = np.linspace(-5, 5, 25)
x2_range = np.linspace(-5, 5, 25)
x1, x2 = np.meshgrid(x1_range, x2_range)
U = f1(x1, x2)
V = f2(x1, x2)

plt.figure(figsize=(8, 8))
quiv = plt.quiver(
    x1, x2, U, V,
    color='b',
    alpha=0.7,
    angles='xy',
    scale_units='xy',
    scale=5,
    width=0.002          
)
plt.xlabel('x₁')
plt.ylabel('x₂')
plt.title('Phase Portrait of 2D System')
plt.axis('equal')
plt.xlim([-5, 5])
plt.ylim([-5, 5])
plt.grid(True)

num_trajectories = 700
np.random.seed(42)

def system(t, z):
    x1, x2 = z
    return [f1(x1, x2), f2(x1, x2)]

lines = []
t_span = [0, 6]
all_trajectories = []
min_length = 7
i = 0 
rejected_count = 0
while len(all_trajectories) < num_trajectories:
    ic = np.random.uniform(-5, 5, size=2)
    sol = solve_ivp(system, t_span, ic, t_eval=np.linspace(*t_span, 400))
    max_val = max(np.abs(sol.y[0]).max(), np.abs(sol.y[1]).max())
    solution = []
    i = 0
    for point_0 in sol.y[0]:
        point_1 = sol.y[1][i]
        if point_0 < 5 and point_0 > -5 and point_1 < 5 and point_1 > -5:
            solution.append([point_0, point_1])
        i += 1
            
    all_trajectories.append(solution)
    line, = plt.plot([k[0] for k in solution],  [k[1] for k in solution], 'r', linewidth=1.5)
    lines.append(line)


eq1 = plt.plot(0, 0, 'ko', markersize=8)
eq2 = plt.plot(3**0.5, 0, 'ks', markersize=8)
eq3 = plt.plot(-3**0.5, 0, 'ks', markersize=8)
plt.legend(
    [quiv, lines[0], eq1[0], eq2[0]],
    ['Vector field', 'Trajectories', 'Stable Eq (0,0)', 'Saddle Eq (±√3,0)'],
    loc='upper right'
)
plt.show()
print(f"Generated {num_trajectories} random trajectories")
print(f"Rejected {rejected_count} short trajectories during generation.")
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Generated 700 random trajectories
# Rejected 0 short trajectories during generation.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

def f1(x1, x2):
    return x2

def f2(x1, x2):
    return -x1 + (1/3)*x1**3 - x2

x1_range = np.linspace(-5, 5, 25)
x2_range = np.linspace(-5, 5, 25)
x1, x2 = np.meshgrid(x1_range, x2_range)
U = f1(x1, x2)
V = f2(x1, x2)

plt.figure(figsize=(8, 8))
quiv = plt.quiver(
    x1, x2, U, V,
    color='b',
    alpha=0.7,
    angles='xy',
    scale_units='xy',
    scale=5,
    width=0.002          
)
plt.xlabel('x₁')
plt.ylabel('x₂')
plt.title('Phase Portrait of 2D System')
plt.axis('equal')
plt.xlim([-5, 5])
plt.ylim([-5, 5])
plt.grid(True)

num_trajectories = 700
np.random.seed(42)

def system(t, z):
    x1, x2 = z
    return [f1(x1, x2), f2(x1, x2)]

lines = []
t_span = [0, 6]
all_trajectories = []
min_length = 7
i = 0 
rejected_count = 0
while len(all_trajectories) < num_trajectories:
    ic = np.random.uniform(-5, 5, size=2)
    sol = solve_ivp(system, t_span, ic, t_eval=np.linspace(*t_span, 400))
    max_val = max(np.abs(sol.y[0]).max(), np.abs(sol.y[1]).max())
    solution = []
    i = 0
    for point_0 in sol.y[0]:
        point_1 = sol.y[1][i]
        if point_0 < 5 and point_0 > -5 and point_1 < 5 and point_1 > -5:
            solution.append([point_0, point_1])
        i += 1
            
    all_trajectories.append(solution)
    line, = plt.plot([k[0] for k in solution],  [k[1] for k in solution], 'r', linewidth=1.5)
    lines.append(line)


eq1 = plt.plot(0, 0, 'ko', markersize=8)
eq2 = plt.plot(3**0.5, 0, 'ks', markersize=8)
eq3 = plt.plot(-3**0.5, 0, 'ks', markersize=8)
plt.legend(
    [quiv, lines[0], eq1[0], eq2[0]],
    ['Vector field', 'Trajectories', 'Stable Eq (0,0)', 'Saddle Eq (±√3,0)'],
    loc='upper right'
)
plt.show()
print(f"Generated {num_trajectories} random trajectories")
print(f"Rejected {rejected_count} short trajectories during generation.")


import torch.nn as nn
import math
import torch 
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

class AttentionHead(nn.Module):
    def __init__(self, n_embd, head_size, dropout_rate):
        super().__init__()
        self.head_size = head_size
        self.w_key = nn.Linear(n_embd, head_size, bias=False)
        self.w_query = nn.Linear(n_embd, head_size, bias=False)
        self.w_value = nn.Linear(n_embd, head_size, bias=False)
        self.dropout = nn.Dropout(dropout_rate)
    
    def forward(self, embedded_input, block_size):
        K = self.w_key(embedded_input)
        Q = self.w_query(embedded_input)
        V = self.w_value(embedded_input)
        raw_attention_scores = (Q @ K.transpose(-2,-1)) * (1.0 / math.sqrt(self.head_size))
        masked_attention_scores = raw_attention_scores.masked_fill(
            torch.tril(torch.ones(block_size, block_size)) == 0, float('-inf')
        )
        attention_probabilities = self.dropout(F.softmax(masked_attention_scores, dim=-1))
        return attention_probabilities @ V

class MultiHeadAttention(nn.Module):
    def __init__(self, n_embd, num_heads, head_size, dropout_rate):
        super().__init__()
        self.heads = nn.ModuleList([
            AttentionHead(n_embd, head_size, dropout_rate) for _ in range(num_heads)
        ])
        self.w_attn_output = nn.Linear(head_size * num_heads, n_embd, bias=False)
        self.dropout = nn.Dropout(dropout_rate)
    
    def forward(self, embedded_input, block_size):
        head_outputs = [head(embedded_input, block_size) for head in self.heads]
        concatenated = torch.cat(head_outputs, dim=-1)
        return self.dropout(self.w_attn_output(concatenated))
    
class FeedForward(nn.Module):
    def __init__(self, n_embd, dropout_rate):
        super().__init__()
        self.w_ffn = nn.Linear(n_embd, 4 * n_embd)
        self.w_ffn_output = nn.Linear(4 * n_embd, n_embd)
        self.dropout = nn.Dropout(dropout_rate)
    
    def forward(self, x):
        FFN_activations = F.relu(self.w_ffn(x))
        return self.dropout(self.w_ffn_output(FFN_activations))
    
class TransformerBlock(nn.Module):
    def __init__(self, n_embd, num_heads, head_size, dropout_rate):
        super().__init__()
        self.attention = MultiHeadAttention(n_embd, num_heads, head_size, dropout_rate)
        self.norm_attn_gain = nn.Parameter(torch.ones(n_embd))
        self.norm_attn_bias = nn.Parameter(torch.zeros(n_embd))
        self.ffn = FeedForward(n_embd, dropout_rate)
        self.norm_logits_gain = nn.Parameter(torch.ones(n_embd))
        self.norm_logits_bias = nn.Parameter(torch.zeros(n_embd))
    
    def forward(self, embedded_input, block_size):
        # Attention
        attention_output = self.attention(embedded_input, block_size)
        # Add + Norm
        FFN_in_raw = attention_output + embedded_input
        FFN_in_normalized = self.norm_attn_gain * (FFN_in_raw - FFN_in_raw.mean(dim=-1, keepdim=True)) + self.norm_attn_bias
        # FFN
        FFN_output = self.ffn(FFN_in_normalized)
        # Add + Norm
        logits_raw = FFN_output + FFN_in_normalized
        logits_normalized = self.norm_logits_gain * (logits_raw - logits_raw.mean(dim=-1, keepdim=True)) + self.norm_logits_bias
        return logits_normalized


class TransformerModel(nn.Module):
    def __init__(self, n_embd, num_heads, head_size, dropout_rate, num_layers=1):
        super().__init__()
        self.embed = nn.Linear(2, n_embd, bias=False)
        self.blocks = nn.ModuleList([
            TransformerBlock(n_embd, num_heads, head_size, dropout_rate) for _ in range(num_layers)
        ])
        self.w_logits_output = nn.Linear(n_embd, 2)
    
    def forward(self, input_data, block_size):
        embedded_input = self.embed(input_data)
        x = embedded_input
        for block in self.blocks:
            x = block(x, block_size)
        # Linear
        logits = self.w_logits_output(x)
        return logits


# Train Model
n_epochs = 3
block_size = 16
n_embd = 128
num_heads = 4
batch_size = 64
head_size = n_embd // num_heads
dropout_rate = 0.1
num_layers = 3
n_epochs = 10
model = TransformerModel(n_embd, num_heads, head_size, dropout_rate, num_layers)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Prep Data
inputs = []
for trajectory in all_trajectories:
    for i in range(len(trajectory) - block_size):
        inputs.append(trajectory[i:i + block_size + 1])
training_inputs = inputs[:int(len(inputs)*.75)]
test_inputs = inputs[int(len(inputs)*.75):]
training_dataset = TensorDataset(torch.stack([torch.tensor(inp, dtype=torch.float32) for inp in training_inputs]))
train_loader = DataLoader(training_dataset, batch_size=32, shuffle=True)

for epoch in range(n_epochs):
    epoch_loss = 0
    for batch in train_loader:
        input_sequences = batch[0]  # Shape: (batch_size, block_size + 1)
        input_data = input_sequences[:, :block_size, :]  # Shape: (batch_size, block_size, 1)
        targets = input_sequences[:, -1, :]  # Shape: (batch_size,)
        
        
        logits = model(input_data, block_size)

        # Backpropagation
        predictions = logits[:, -1, :]  # Shape: (batch_size,)
        loss = F.mse_loss(predictions, targets)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
    print(f"Epoch {epoch}, Loss: {epoch_loss / len(training_inputs):.6f}")

total_params = sum(p.numel() for p in model.parameters())
for i, (name, p) in enumerate(model.named_parameters()):
    print(f"Param {i} ({name}): {p.numel()} parameters, shape: {p.shape}")
print(f"\nTotal parameters: {total_params}")
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Generated 700 random trajectories
# Rejected 0 short trajectories during generation.
# Epoch 0, Loss: 0.000298
# Epoch 1, Loss: 0.000035
# Epoch 2, Loss: 0.000024
# Epoch 3, Loss: 0.000017
# Epoch 4, Loss: 0.000009
# Epoch 5, Loss: 0.000006
# Epoch 6, Loss: 0.000026
# Epoch 7, Loss: 0.000001
# Epoch 8, Loss: 0.000002
# Epoch 9, Loss: 0.000002
# Param 0 (embed.weight): 256 parameters, shape: torch.Size([128, 2])
# Param 1 (blocks.0.norm_attn_gain): 128 parameters, shape: torch.Size([128])
# Param 2 (blocks.0.norm_attn_bias): 128 parameters, shape: torch.Size([128])
# Param 3 (blocks.0.norm_logits_gain): 128 parameters, shape: torch.Size([128])
# Param 4 (blocks.0.norm_logits_bias): 128 parameters, shape: torch.Size([128])
# Param 5 (blocks.0.attention.heads.0.w_key.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 6 (blocks.0.attention.heads.0.w_query.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 7 (blocks.0.attention.heads.0.w_value.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 8 (blocks.0.attention.heads.1.w_key.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 9 (blocks.0.attention.heads.1.w_query.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 10 (blocks.0.attention.heads.1.w_value.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 11 (blocks.0.attention.heads.2.w_key.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 12 (blocks.0.attention.heads.2.w_query.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 13 (blocks.0.attention.heads.2.w_value.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 14 (blocks.0.attention.heads.3.w_key.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 15 (blocks.0.attention.heads.3.w_query.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 16 (blocks.0.attention.heads.3.w_value.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 17 (blocks.0.attention.w_attn_output.weight): 16384 parameters, shape: torch.Size([128, 128])
# Param 18 (blocks.0.ffn.w_ffn.weight): 65536 parameters, shape: torch.Size([512, 128])
# Param 19 (blocks.0.ffn.w_ffn.bias): 512 parameters, shape: torch.Size([512])
# Param 20 (blocks.0.ffn.w_ffn_output.weight): 65536 parameters, shape: torch.Size([128, 512])
# Param 21 (blocks.0.ffn.w_ffn_output.bias): 128 parameters, shape: torch.Size([128])
# Param 22 (blocks.1.norm_attn_gain): 128 parameters, shape: torch.Size([128])
# Param 23 (blocks.1.norm_attn_bias): 128 parameters, shape: torch.Size([128])
# Param 24 (blocks.1.norm_logits_gain): 128 parameters, shape: torch.Size([128])
# Param 25 (blocks.1.norm_logits_bias): 128 parameters, shape: torch.Size([128])
# Param 26 (blocks.1.attention.heads.0.w_key.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 27 (blocks.1.attention.heads.0.w_query.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 28 (blocks.1.attention.heads.0.w_value.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 29 (blocks.1.attention.heads.1.w_key.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 30 (blocks.1.attention.heads.1.w_query.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 31 (blocks.1.attention.heads.1.w_value.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 32 (blocks.1.attention.heads.2.w_key.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 33 (blocks.1.attention.heads.2.w_query.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 34 (blocks.1.attention.heads.2.w_value.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 35 (blocks.1.attention.heads.3.w_key.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 36 (blocks.1.attention.heads.3.w_query.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 37 (blocks.1.attention.heads.3.w_value.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 38 (blocks.1.attention.w_attn_output.weight): 16384 parameters, shape: torch.Size([128, 128])
# Param 39 (blocks.1.ffn.w_ffn.weight): 65536 parameters, shape: torch.Size([512, 128])
# Param 40 (blocks.1.ffn.w_ffn.bias): 512 parameters, shape: torch.Size([512])
# Param 41 (blocks.1.ffn.w_ffn_output.weight): 65536 parameters, shape: torch.Size([128, 512])
# Param 42 (blocks.1.ffn.w_ffn_output.bias): 128 parameters, shape: torch.Size([128])
# Param 43 (blocks.2.norm_attn_gain): 128 parameters, shape: torch.Size([128])
# Param 44 (blocks.2.norm_attn_bias): 128 parameters, shape: torch.Size([128])
# Param 45 (blocks.2.norm_logits_gain): 128 parameters, shape: torch.Size([128])
# Param 46 (blocks.2.norm_logits_bias): 128 parameters, shape: torch.Size([128])
# Param 47 (blocks.2.attention.heads.0.w_key.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 48 (blocks.2.attention.heads.0.w_query.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 49 (blocks.2.attention.heads.0.w_value.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 50 (blocks.2.attention.heads.1.w_key.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 51 (blocks.2.attention.heads.1.w_query.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 52 (blocks.2.attention.heads.1.w_value.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 53 (blocks.2.attention.heads.2.w_key.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 54 (blocks.2.attention.heads.2.w_query.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 55 (blocks.2.attention.heads.2.w_value.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 56 (blocks.2.attention.heads.3.w_key.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 57 (blocks.2.attention.heads.3.w_query.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 58 (blocks.2.attention.heads.3.w_value.weight): 4096 parameters, shape: torch.Size([32, 128])
# Param 59 (blocks.2.attention.w_attn_output.weight): 16384 parameters, shape: torch.Size([128, 128])
# Param 60 (blocks.2.ffn.w_ffn.weight): 65536 parameters, shape: torch.Size([512, 128])
# Param 61 (blocks.2.ffn.w_ffn.bias): 512 parameters, shape: torch.Size([512])
# Param 62 (blocks.2.ffn.w_ffn_output.weight): 65536 parameters, shape: torch.Size([128, 512])
# Param 63 (blocks.2.ffn.w_ffn_output.bias): 128 parameters, shape: torch.Size([128])
# Param 64 (w_logits_output.weight): 256 parameters, shape: torch.Size([2, 128])
# Param 65 (w_logits_output.bias): 2 parameters, shape: torch.Size([2])
#
# Total parameters: 593794

# %%
# ==========================================
# INFERENCE & VISUALIZATION
# ==========================================
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

model.eval()
print("Generating inference plots...")

# Setup plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))

# 1. Ground Truth Phase Portrait (Vector Field)
x1_range = np.linspace(-5, 5, 20)
x2_range = np.linspace(-5, 5, 20)
X1, X2 = np.meshgrid(x1_range, x2_range)
U = f1(X1, X2)
V = f2(X1, X2)
ax1.quiver(X1, X2, U, V, color='gray', alpha=0.3)
ax2.quiver(X1, X2, U, V, color='gray', alpha=0.3)

# 2. Generate Autoregressive Trajectories
np.random.seed(123)  # Different seed for test trajectories
num_test_traj = 100
start_points = np.random.uniform(-4, 4, size=(num_test_traj, 2))

for idx, start in enumerate(start_points):
    # --- A. Get True Trajectory ---
    sol = solve_ivp(system, [0, 10], start, t_eval=np.linspace(0, 10, 200))
    true_traj = sol.y.T
    
    ax1.plot(true_traj[:, 0], true_traj[:, 1], linewidth=1.5, alpha=0.7)
    
    # --- B. Neural Network Prediction ---
    # Initialize with first 'block_size' points from truth to prime the model
    initial_seq = true_traj[:block_size]
    current_seq = torch.tensor(initial_seq, dtype=torch.float32).unsqueeze(0)
    
    pred_traj = list(initial_seq)
    
    with torch.no_grad():
        for _ in range(200 - block_size):
            # Predict delta
            delta_pred = model(current_seq, block_size)[:, -1, :]  # Shape (1, 2)
            
            # Calculate next point: last_point + delta
            last_point = current_seq[:, -1, :]
            next_point = last_point + delta_pred
            
            # Update sequence: slide window
            next_point_unsqueezed = next_point.unsqueeze(1)
            current_seq = torch.cat((current_seq[:, 1:, :], next_point_unsqueezed), dim=1)
            
            pred_traj.append(next_point.cpu().numpy()[0])
    
    # Denormalize for plotting
    pred_traj_np = np.array(pred_traj)
    
    # Plot
    ax2.plot(pred_traj_np[:, 0], pred_traj_np[:, 1], linewidth=1.5, alpha=0.7, linestyle='--')

# Styling
ax1.set_title("Ground Truth Physics", fontsize=14, fontweight='bold')
ax2.set_title("Transformer Generated Dynamics", fontsize=14, fontweight='bold')

for ax in [ax1, ax2]:
    ax.set_xlim(-5, 5)
    ax.set_ylim(-5, 5)
    ax.set_xlabel('x₁', fontsize=12)
    ax.set_ylabel('x₂', fontsize=12)
    ax.grid(True, alpha=0.3)
    # Mark equilibrium points
    ax.plot(0, 0, 'ro', markersize=8, label='Unstable')
    ax.plot(np.sqrt(3), 0, 'go', markersize=8, label='Stable')
    ax.plot(-np.sqrt(3), 0, 'go', markersize=8)
    ax.legend(loc='upper right')

plt.tight_layout()
plt.show()

print("Visualization complete!")
# Out:
# Generating inference plots...
# Visualization complete!
